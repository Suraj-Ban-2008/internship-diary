# %%
print('Day5')
# Out:
# Day5

# %%
print('python')
# Out:
# python

# %% [markdown]
# # list

# %%
l=[23,45,67,89,12]

# %%
print(l)
# Out:
# [23, 45, 67, 89, 12]

# %%
l1=[23,45,67,89,12,'python','java',23,45]

# %%
l1
# Out:
# [23, 45, 67, 89, 12, 'python', 'java', 23, 45]

# %%
l1[3]
# Out:
# 89

# %%
l1[-3]
# Out:
# 'java'

# %%
l1[1]=100

# %% [markdown]
# #

# %%
l1
# Out:
# [23, 100, 67, 89, 12, 'python', 'java', 23, 45]

# %%
l2=[23,45,21,True,'python',45.76]

# %%
l2[3]
# Out:
# True

# %%
l=[21,23,45,67,89,11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[1:4]
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
l[0:5:2]
# Out:
# [21, 45, 89]

# %%
l[0:20:2]
# Out:
# [21, 45, 89]

# %%
l[::2]
# Out:
# [21, 45, 89]

# %%
l[1:6:2]
# Out:
# [23, 67, 11]

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
del l[-2]

# %%
l
# Out:
# [21, 23, 45, 67, 11]

# %%
del l

# %%
# membership operator

# %%
l1
# Out:
# [23, 100, 67, 89, 12, 'python', 'java', 23, 45]

# %%
89 in l1
# Out:
# True

# %%
456 in l1
# Out:
# False

# %%
'ok'*3
# Out:
# 'okokok'

# %%
l1*2
# Out:
# [23,
#  100,
#  67,
#  89,
#  12,
#  'python',
#  'java',
#  23,
#  45,
#  23,
#  100,
#  67,
#  89,
#  12,
#  'python',
#  'java',
#  23,
#  45]

# %%
l=[21,100,200,300,89,11]

# %% [markdown]
# l*2

# %%
l*2
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
l+[60,70,80]
# Out:
# [21, 100, 200, 300, 89, 11, 60, 70, 80]

# %%
l3=[22,33,44,55]
l4=[66,77,88,99]

# %%
l3+l4
# Out:
# [22, 33, 44, 55, 66, 77, 88, 99]

# %%
#iteration over list

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
# iterate over list and print square of each elemnet

# %%
for i in l:
    print(i*i,end=' ')
# Out:
# 441 10000 40000 90000 7921 121

# %%
#print odd numbers only

# %%
for i in l:
    if i%2==1:
        print(i)
# Out:
# 21
# 89
# 11

# %%
# list comprehension ->[expression for loop if_condition]

# %%
new=[i**2 for i in l]

# %%
new
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
new2=[i for i in l if i%2==1]

# %%
new2
# Out:
# [21, 89, 11]

# %%
names=['Aryan','atharv','sammruddhi','swaraj','Sukanya','shivraj']

# %% [raw]
# #create the new list with names starts with 's' 'S'

# %%
for i in names:
    if i[0]=='s' or i[0]=='S':
        print(i)
# Out:
# sammruddhi
# swaraj
# Sukanya
# shivraj

# %%
min(l)
# Out:
# 11

# %%
max(l)
# Out:
# 300

# %% [raw]
# sorted(l)

# %%
sorted(l,reverse=True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %%
#append

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1=[1,2,3]
l2=[1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1]=250

# %%
l1
# Out:
# [1, 2, 3, [100, 250]]

# %%
#inseert

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l.insert(1,78)

# %%
l
# Out:
# [21, 78, 100, 200, 300, 89, 11, 1000]

# %%
l.remove(78)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
#pop

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.pop(3)
# Out:
# 300

# %%
l
# Out:
# [21, 100, 200, 89, 11]

# %%
l.index(89)
# Out:
# 3

# %%
l.sort()

# %%
l
# Out:
# [11, 21, 89, 100, 200]

# %%
l.sort(reverse=True)
l
# Out:
# [200, 100, 89, 21, 11]
