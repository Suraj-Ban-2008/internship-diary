# %% [markdown]
# ## pandas

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#1D data structures in pandas

# %%
# Pands series

# %%
s=pd.Series([10,20,30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1=pd.Series([11,22,33,44])

# %%
s1
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
# With custom Index


s1=pd.Series([10,20,30],index=['a','b','c'])

# %%
s1
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s2=pd.Series(['suraj',18,450],index=['name','age','marks'])

# %%
s2
# Out:
# name     suraj
# age         18
# marks      450
# dtype: object

# %%
# from Dictionary

# %%
data={'name':'suraj','age':18,'marks':490}

# %%
s=pd.Series(data)

# %%
s
# Out:
# name     suraj
# age         18
# marks      490
# dtype: object

# %%
data1={'name':'viraj','subject':'science','marks':100}

# %%
s=pd.Series(data1)

# %%
s
# Out:
# name         viraj
# subject    science
# marks          100
# dtype: object

# %%
# from a single value

# %%
s=pd.Series(5,index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
s1=pd.Series('suraj',index=[0,1,2,3])

# %%
s1
# Out:
# 0    suraj
# 1    suraj
# 2    suraj
# 3    suraj
# dtype: object

# %%
# Attributes

# %%
s=pd.Series([10,20,30],index=['a','b','c',])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
s.ndim
# Out:
# 1

# %%
# Data manipulation

# %%
s=pd.Series([11,22,33])

# %%
s
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
s*3
# Out:
# 0    33
# 1    66
# 2    99
# dtype: int64

# %%
# Handling missing values

# %%
s1=pd.Series([10,None,12])

# %%
s1
# Out:
# 0    10.0
# 1     NaN
# 2    12.0
# dtype: float64

# %%
s1.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s1.dropna()
# Out:
# 0    10.0
# 2    12.0
# dtype: float64

# %%
s1.fillna(11)
# Out:
# 0    10.0
# 1    11.0
# 2    12.0
# dtype: float64

# %%
# INdexing

# %%
s=pd.Series([10,20,30],index=['a','b','c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['b']
# Out:
# np.int64(20)

# %%
s['c']
# Out:
# np.int64(30)
