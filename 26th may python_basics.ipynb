# %%
name = "Suraj"

# %%
name.lower()
# Out:
# 'suraj'

# %%
name=name.lower()

# %%
name
# Out:
# 'suraj'

# %%
name.upper()
# Out:
# 'SURAJ'

# %%
name=name.upper()

# %%
name
# Out:
# 'SURAJ'

# %%
name.title()
# Out:
# 'Suraj'

# %%
name="Suraj"

# %%
name.swapcase()
# Out:
# 'sURAJ'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1="ok"
name2="123"
name3="ok123"

# %%
name.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isnumeric()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name2.isalnum()
# Out:
# True

# %%
name3.isalnum()
# Out:
# True

# %%
name=" pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith("p")
# Out:
# False

# %%
name.startswith(' p')
# Out:
# True

# %%
name.endswith("pune")
# Out:
# False

# %%
name.endswith("e")
# Out:
# False

# %%
name.endswith("p ")
# Out:
# False

# %%
name.endswith("e ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'pune '

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u','oo')
# Out:
# ' poone '

# %% [markdown]
# # operator

# %%
a=5
b=17

# %%
a+b
# Out:
# 22

# %%
b-a
# Out:
# 12

# %%
b/a
# Out:
# 3.4

# %%
a*b
# Out:
# 85

# %%
a**b
# Out:
# 762939453125

# %%
b**a
# Out:
# 1419857

# %%
b//a
# Out:
# 3

# %%
b%a
# Out:
# 2

# %%
#assighment opertaors

# %%
z=5

# %%
z
# Out:
# 5

# %%
z=z+3

# %%
z
# Out:
# 8

# %%
z+=3

# %%
z
# Out:
# 11

# %%
z-=3

# %%
z
# Out:
# 8

# %%
z*=3

# %%
z
# Out:
# 24

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not b
# Out:
# True

# %%
# identity

# %%
a=5
b=5

# %%
id(a),id(b)
# Out:
# (140721478546472, 140721478546472)

# %%
a is b
# Out:
# True

# %%
a=[3,4]
b=[3,4]

# %%
a is b
# Out:
# False

# %%
id(a),id(b)
# Out:
# (1889085286336, 1889084932288)

# %%
a is not b
# Out:
# True

# %%
z=a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)

# %%
z
# Out:
# [3, 4, 10]

# %%
l=[2,3,4,6,9]

# %%
6 in l
# Out:
# True

# %%
10 in l
# Out:
# False

# %%
10 not in l
# Out:
# True

# %%
2 not in l
# Out:
# False

# %% [markdown]
# # precendence and association

# %%
5+2-1
# Out:
# 6

# %%
2**6
# Out:
# 64

# %%
2**5
# Out:
# 32

# %%
2**2**3
# Out:
# 256

# %%
2**8
# Out:
# 256

# %%
3/2
# Out:
# 1.5

# %%
2**1.5
# Out:
# 2.8284271247461903

# %%
2**3/1
# Out:
# 8.0

# %% [markdown]
# # Print Function:-

# %%
name="Atharv"

# %%
mark=99

# %%
print('my name is',name,'and mark are',mark)
# Out:
# my name is Atharv and mark are 99

# %%
print("my name is %s and marks is %i"%(name,mark))
# Out:
# my name is Atharv and marks is 99

# %%
print("my name is %s and marks is %f"%(name,mark))
# Out:
# my name is Atharv and marks is 99.000000

# %%
print(f"My name is {name} and marks are{mark}")
# Out:
# My name is Atharv and marks are99

# %% [markdown]
# # Dir and Help

# %%
name
# Out:
# 'Atharv'

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
help(name2.isnumeric)
# Out:
# Help on built-in function isnumeric:
#
# isnumeric() method of builtins.str instance
#     Return True if the string is a numeric string, False otherwise.
#
#     A string is numeric if all characters in the string are numeric and there is at
#     least one character in the string.

# %%
ord('A')  #It return ASCII Value of 'A'
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
chr(65)  #It return Letter of that ASCII Value
# Out:
# 'A'

# %% [markdown]
# # Type Casting

# %%
num1=34

# %%
num2=44.56

# %%
num3="ok"

# %%
num2=float(num1)

# %%
num2
# Out:
# 34.0

# %%
num1
# Out:
# 34

# %%
float(num1)
# Out:
# 34.0

# %%
int(44)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
int("ok")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 int("ok")
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %% [markdown]
# # User Input

# %%
a=(input("Enter The Value of a")) 
b=(input("Enter The Value of b"))
z=a+b
print("Addition is ",z)
# Out:
# Enter The Value of a 78
# Enter The Value of b 45
# Addition is  7845

# %%
'''
read the time in second as user input
and print the time in the format as hour:minutes:seconds

eg:
input ->125sec
output ->00:02:05
'''
# Out:
# '\nread the time in second as user input\nand print the time in the format as hour:minutes:seconds\n\neg:\ninput ->125sec\noutput ->00:02:05\n'

# %%
sec=int(input("Enter the time sec:")) #125
ho=sec//3600  
min1=sec//60
second=sec%60
print(f"{ho}:{min1}:{second}")
# Out:
# Enter the time sec: 125
# 0:2:5
